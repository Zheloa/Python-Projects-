# %% [markdown]
# ## Task #1

# %%
import pandas as pd

# %%
survey_df = pd.read_csv('survey_results_public.csv')

# %%
survey_df.columns.tolist()
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'Check',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'TechDoc',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'BuyNewTool',
#  'BuildvsBuy',
#  'TechEndorse',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'LanguageAdmired',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'DatabaseAdmired',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'PlatformAdmired',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'WebframeAdmired',
#  'EmbeddedHaveWorkedWith',
#  'EmbeddedWantToWorkWith',
#  'EmbeddedAdmired',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'MiscTechAdmired',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'ToolsTechAdmired',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
# ...

# %%
survey_df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
survey_df['ResponseId'].nunique()
# Out:
# 65437

# %% [markdown]
# ## Task #2

# %%
survey_df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
questions_from_survey = survey_df.columns
questions_from_schema = schema_df.qname
print(questions_from_survey)
print(questions_from_schema)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)
# 0          MainBranch
# 1                 Age
# 2          Employment
# 3          RemoteWork
# 4               Check
#            ...
# 82     JobSatPoints_7
# 83     JobSatPoints_8
# 84     JobSatPoints_9
# 85    JobSatPoints_10
# 86    JobSatPoints_11
# Name: qname, Length: 87, dtype: object

# %% [raw]
# questions = set(questions_from_survey) & set(questions_from_schema)

# %%
print(questions)
# Out:
# {'JobSatPoints_4', 'JobSatPoints_6', 'SOPartFreq', 'Employment', 'TBranch', 'Knowledge_1', 'LearnCodeOnline', 'Country', 'LearnCode', 'CompTotal', 'ProfessionalQuestion', 'SurveyLength', 'CodingActivities', 'Check', 'JobSatPoints_7', 'Knowledge_9', 'WorkExp', 'Knowledge_8', 'JobSatPoints_5', 'YearsCode', 'SOVisitFreq', 'Frequency_3', 'JobSat', 'Knowledge_4', 'YearsCodePro', 'TechEndorse', 'ProfessionalCloud', 'TimeSearching', 'AIEthics', 'Knowledge_5', 'JobSatPoints_10', 'SOHow', 'NEWSOSites', 'SOAccount', 'JobSatPoints_9', 'Age', 'AIThreat', 'PurchaseInfluence', 'RemoteWork', 'DevType', 'EdLevel', 'Frequency_2', 'MainBranch', 'Frustration', 'Knowledge_2', 'Industry', 'JobSatPoints_8', 'JobSatPoints_1', 'Knowledge_3', 'JobSatPoints_11', 'SOComm', 'TimeAnswering', 'AIChallenges', 'BuildvsBuy', 'ProfessionalTech', 'Knowledge_7', 'AISent', 'ICorPM', 'AISelect', 'BuyNewTool', 'AIBen', 'Knowledge_6', 'Currency', 'AIAcc', 'TechDoc', 'SurveyEase', 'AIComplex', 'OrgSize', 'Frequency_1'}

# %%
survey_df.dropna(subset = questions).shape[0]
# Out:
# 6306

# %% [markdown]
# ## Task #3

# %%
print(survey_df.WorkExp.mean())
# Out:
# 11.46695663901814

# %%
print(survey_df.WorkExp.mode())
# Out:
# 0    3.0
# Name: WorkExp, dtype: float64

# %%
print(survey_df.WorkExp.median())
# Out:
# 9.0

# %% [markdown]
# ## Task #4

# %%
survey_df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
survey_df.RemoteWork.unique()
# Out:
# array(['Remote', nan, 'In-person', 'Hybrid (some remote, some in-person)'],
#       dtype=object)

# %%
(survey_df.RemoteWork == 'Remote').sum()
# Out:
# 20831

# %%
survey_df[survey_df.RemoteWork == 'Remote'].shape[0]
# Out:
# 20831

# %% [markdown]
# ## Task #5

# %%
survey_df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
survey_df.sample(15)
# Out:
#        ResponseId                                         MainBranch  \
# 6399         6400                     I am a developer by profession
# 1931         1932                     I am a developer by profession
# 13363       13364                     I am a developer by profession
# 5780         5781  I am not primarily a developer, but I write co...
# 7209         7210                     I am a developer by profession
# 29856       29857                              I am learning to code
# 16625       16626                     I am a developer by profession
# 46555       46556                     I am a developer by profession
# 58938       58939                        I code primarily as a hobby
# 25041       25042                     I am a developer by profession
# 23688       23689  I am not primarily a developer, but I write co...
# 29381       29382                     I am a developer by profession
# 34124       34125                     I am a developer by profession
# ...

# %%
survey_df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
survey_df.LanguageHaveWorkedWith
# Out:
# 0                                                      NaN
# 1        Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                       C#
# 3        C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4                  C++;HTML/CSS;JavaScript;Lua;Python;Rust
#                                ...
# 65432                                                  NaN
# 65433                                                  NaN
# 65434                                                  NaN
# 65435             C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65436     C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: object

# %%
survey_df.LanguageHaveWorkedWith.str.lower()
# Out:
# 0                                                      NaN
# 1        bash/shell (all shells);go;html/css;java;javas...
# 2                                                       c#
# 3        c;c++;html/css;java;javascript;php;powershell;...
# 4                  c++;html/css;javascript;lua;python;rust
#                                ...
# 65432                                                  NaN
# 65433                                                  NaN
# 65434                                                  NaN
# 65435             c;c++;go;lua;objective-c;python;rust;sql
# 65436     c;html/css;java;javascript;php;python;typescript
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: object

# %%
finding_python = survey_df.LanguageHaveWorkedWith.str.lower().str.contains('python', na = False)
finding_python
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 65432    False
# 65433    False
# 65434    False
# 65435     True
# 65436     True
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: bool

# %%
survey_df.loc[finding_python].shape[0]
# Out:
# 30795

# %%
perc_python = survey_df.loc[finding_python].shape[0]/survey_df['ResponseId'].nunique()
perc_python
# Out:
# 0.47060531503583597

# %% [markdown]
# ## Task #6

# %%
survey_df.LearnCode
# Out:
# 0                                   Books / Physical media
# 1        Books / Physical media;Colleague;On the job tr...
# 2        Books / Physical media;Colleague;On the job tr...
# 3        Other online resources (e.g., videos, blogs, f...
# 4        Other online resources (e.g., videos, blogs, f...
#                                ...
# 65432    On the job training;School (i.e., University, ...
# 65433                                                  NaN
# 65434    Other online resources (e.g., videos, blogs, f...
# 65435    On the job training;Other online resources (e....
# 65436                                                  NaN
# Name: LearnCode, Length: 65437, dtype: object

# %%
finding_online = survey_df.LearnCode.str.lower().str.contains('online', na = False)
finding_online
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 65432    False
# 65433    False
# 65434     True
# 65435     True
# 65436    False
# Name: LearnCode, Length: 65437, dtype: bool

# %%
survey_df.loc[finding_online].shape[0]
# Out:
# 54061

# %% [markdown]
# ## Task #7

# %%
python_coding_df = survey_df.loc[finding_python]
python_country_df = python_coding_df.groupby('Country')
python_country_df

# %%
survey_df.ConvertedCompYearly[finding_python].agg(['mean', 'median'])
# Out:
# mean      88968.298705
# median    67911.000000
# Name: ConvertedCompYearly, dtype: float64

# %%
survey_df[finding_python].groupby(by = 'Country').agg({'ConvertedCompYearly' : ['mean', 'median']})
# Out:
#                                      ConvertedCompYearly
#                                                     mean    median
# Country
# Afghanistan                                  4543.000000    4768.5
# Albania                                     56295.000000   56295.0
# Algeria                                      9053.285714    6230.0
# Andorra                                    193331.000000  193331.0
# Angola                                          6.000000       6.0
# ...                                                  ...       ...
# Venezuela, Bolivarian Republic of...        21500.000000    7100.0
# Viet Nam                                    14014.562500   10180.0
# Yemen                                       10297.333333    5333.0
# Zambia                                      28123.666667   22803.0
# Zimbabwe                                    37500.000000   18000.0
#
# [173 rows x 2 columns]

# %% [markdown]
# ## Task#8

# %%
top_comp = survey_df[['ConvertedCompYearly', 'EdLevel']].sort_values('ConvertedCompYearly', ascending = False)

# %%
top_comp.head(5)
# Out:
#        ConvertedCompYearly                                         EdLevel
# 15837           16256603.0    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12723           13818022.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 28379            9000000.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 17593            6340564.0    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17672            4936778.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
